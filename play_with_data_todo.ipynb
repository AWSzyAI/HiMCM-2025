# %%
# !pip install pandas openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# ...
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...

# %%
import pandas as pd

# %%
Top500 = pd.read_excel('./data/TOP500_202406.xlsx')
# Top500 = pd.read_excel('/Users/szy/Library/Mobile Documents/com~apple~CloudDocs/2025/2025-09-10 HiMCM-2025/2025-09-17 授课2 Python/data/TOP500_202406.xlsx')

Top500.head(10)
# Top500
# Out:
#    Rank  Previous Rank  First Appearance  First Rank                     Name  \
# 0     1            1.0                59           1                 Frontier
# 1     2            2.0                62           2                   Aurora
# 2     3            3.0                62           3                    Eagle
# 3     4            4.0                55           1     Supercomputer Fugaku
# 4     5            5.0                59           3                     LUMI
# 5     6            NaN                63           6                     Alps
# 6     7            6.0                60           4                 Leonardo
# 7     8            8.0                62           8        MareNostrum 5 ACC
# 8     9            7.0                51           1                   Summit
# 9    10            9.0                62           9  Eos NVIDIA DGX SuperPOD
#
#                                             Computer  \
# 0  HPE Cray EX235a, AMD Optimized 3rd Generation ...
# ...

# %%
df_E = pd.read_csv('./data/Emission.csv')
df_E
# Out:
#                year     country Energy type type electricity available  \
# 2023  United States         gas        1640                       4040
# 2023  United States     biomass        8.98                       4040
# 2023  United States         oil        3.66                       4040
# 2023  United States        coal         685                       4040
# 2023  United States        wind         424                       4040
# ...             ...         ...         ...                        ...
# 2023        Belgium       solar        7.19                       95.2
# 2023        Belgium       hydro       0.217                       95.2
# 2023        Belgium  geothermal           0                       95.2
# 2023        Belgium     nuclear        31.3                       95.2
# 2023        Belgium     unknown      0.0014                       95.2
#
#      total electricity available (TWh) type electricity rate(%)  \
# ...
